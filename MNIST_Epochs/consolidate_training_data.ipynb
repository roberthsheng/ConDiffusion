# %%
import torch
from torch import nn, optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import torch.nn.functional as F
import os
import torch
from torch import nn
from torch.optim import Adam
from torch.utils.data import DataLoader, random_split
from torchvision.datasets import MNIST
from torchvision import transforms
from torch.utils.data import TensorDataset, DataLoader
import numpy as np

# %%
# !pip install npy-append-array

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
DATA_PATH = './drive/MyDrive/CS 8395 - C-DiffNet/MNIST_Epochs/new_dataset'

# %%
from npy_append_array import NpyAppendArray

for i in range(10):

  curr_data_path = DATA_PATH + f'/epoch_{i}/'
  consol_data_path = f'./drive/MyDrive/CS 8395 - C-DiffNet/MNIST_Epochs/consolidated_new_data'

  if not os.path.exists(consol_data_path):
    os.makedirs(consol_data_path)
  with NpyAppendArray(consol_data_path + f'/epoch_{i+1}') as npaa:
    for file in os.listdir(curr_data_path):
      if file != '.ipynb_checkpoints':

        data = np.load(curr_data_path + file)
        npaa.append(data)

# %%
sample_load = np.load('./drive/MyDrive/CS 8395 - C-DiffNet/MNIST_Epochs/consolidated_new_data/epoch_1')

# %%
# Out:
# [[ 0.13818479  0.27422184 -0.31762898 ...  0.2085446   0.00578036
#   -0.06644578]
#  [ 0.11890507 -0.0521097  -0.12744147 ... -0.09866139  0.23667602
#    0.07750379]
#  [ 0.02654695  0.07113605 -0.2754685  ...  0.02324109  0.1516393
#    0.25302306]
#  ...
#  [-0.08176855  0.09331173  0.07994052 ...  0.10005926  0.12734921
#    0.11964171]
#  [ 0.08033754  0.08107525  0.00910489 ... -0.10256217  0.11111518
#    0.1396626 ]
#  [ 0.02795419  0.00503146 -0.0889777  ...  0.01631097  0.06340489
#    0.26828057]]
